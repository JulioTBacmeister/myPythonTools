# %%
import esmpy as E
import numpy as np

# %%
# %%time
# Initialize E
E.Manager()

# Define the source grid
src_lon = np.linspace(0, 360, 144, endpoint=False)
src_lat = np.linspace(-90, 90, 73, endpoint=True)
src_grid = E.Grid(np.array([len(src_lon), len(src_lat)]), staggerloc=[E.StaggerLoc.CENTER])
src_lon_par, src_lat_par = [src_grid.get_coords(i) for i in range(2)]
src_lon_par[...] = src_lon.reshape((src_lon.shape[0], 1))
src_lat_par[...] = src_lat.reshape((1, src_lat.shape[0]))

# Define the destination grid
dst_lon = np.linspace(0, 360, 72, endpoint=False)
dst_lat = np.linspace(-90, 90, 36, endpoint=True)
dst_grid = E.Grid(np.array([len(dst_lon), len(dst_lat)]), staggerloc=[E.StaggerLoc.CENTER])
dst_lon_par, dst_lat_par = [dst_grid.get_coords(i) for i in range(2)]
dst_lon_par[...] = dst_lon.reshape((dst_lon.shape[0], 1))
dst_lat_par[...] = dst_lat.reshape((1, dst_lat.shape[0]))

# Create field objects on the source and destination grids
src_field = E.Field(src_grid, name='Source Data')
dst_field = E.Field(dst_grid, name='Destination Data')

# Initialize the source field with some data, for example, a simple pattern
src_field.data[...] = np.sin(src_lon_par * np.pi / 180.0) * np.cos(src_lat_par * np.pi / 180.0)

# Create a regridder object from source to destination
regridder = E.Regrid(src_field, dst_field, regrid_method=E.RegridMethod.BILINEAR,
                        unmapped_action=E.UnmappedAction.IGNORE)

# Perform the regridding
oo = regridder(src_field, dst_field)

# dst_field.data now contains the regridded data

# %%
print(np.shape(src_lon_par))

# %% [raw]
# User
# where were lats and lons actually assigned to anything in src_grid????
# ChatGPT
# Upon closer examination of the provided code and the operations performed on the src_grid object from ESMF (Earth System Modeling Framework), let's clarify how the latitude and longitude values were assigned to the grid:
#
# Assigning Longitude and Latitude Values to the Grid
# The key part of the code where the latitude and longitude values are actually assigned to the src_grid object is here:
#
# python
# Copy code
# src_lon_par, src_lat_par = [src_grid.get_coords(i) for i in range(2)]
# src_lon_par[...] = src_lon.reshape((src_lon.shape[0], 1))
# src_lat_par[...] = src_lat.reshape((1, src_lat.shape[0]))
# Let's break down these steps:
#
# Retrieving Coordinate Arrays:
#
# python
# Copy code
# src_lon_par, src_lat_par = [src_grid.get_coords(i) for i in range(2)]
# This line retrieves the arrays for storing longitude and latitude coordinates directly from src_grid. The method get_coords(i) is called for i in range(2), where 0 typically refers to the longitude axis and 1 to the latitude axis. These arrays (src_lon_par for longitude, src_lat_par for latitude) are where the actual coordinate values will be stored. Before this assignment, these arrays are placeholders within the grid structure, allocated based on the grid's dimensions but not yet filled with meaningful data.
#
# Assigning Longitude Values:
#
# python
# Copy code
# src_lon_par[...] = src_lon.reshape((src_lon.shape[0], 1))
# Here, src_lon is reshaped to ensure it fits the expected 2D shape of the grid's longitude dimension and then assigned to src_lon_par. The [...] syntax is used for in-place modification of the entire array. This step populates the grid's longitude coordinate array with the actual longitude values defined by np.linspace(0, 360, 144, endpoint=False).
#
# Assigning Latitude Values:
#
# python
# Copy code
# src_lat_par[...] = src_lat.reshape((1, src_lat.shape[0]))
# Similarly, src_lat is reshaped to fit the 2D shape of the grid's latitude dimension and assigned to src_lat_par. This populates the grid's latitude coordinate array with the actual latitude values defined by np.linspace(-90, 90, 73, endpoint=True).
#
# Summary
# The src_grid object's latitude and longitude coordinates are assigned through the get_coords method, which retrieves the reference to the internal arrays designated for longitude and latitude. The subsequent assignments with src_lon_par[...] = ... and src_lat_par[...] = ... fill these arrays with the actual geographical coordinates. Thus, after these operations, src_grid has its geographical structuring defined, with each grid cell's center positioned at specific latitude and longitude coordinates. This process effectively "assigns" the latitudes and longitudes to the grid, making it ready for further use in modeling and simulation tasks that require spatially explicit data.
#
# User
# So this line is telling ESMF to expect coordinate values to be placed in src_lon_par and src_lat_par
# src_lon_par, src_lat_par = [src_grid.get_coords(i) for i in range(2)]
# So src_lon_par and src_lat_par are pointing to contents of src_grid??
# ChatGPT
# Yes, that's correct. The line:
#
# python
# Copy code
# src_lon_par, src_lat_par = [src_grid.get_coords(i) for i in range(2)]
# is telling ESMF to retrieve the coordinate arrays from the src_grid object where it expects longitude and latitude values to be placed. The get_coords(i) method is used to access these coordinate arrays directly from the grid. When you do this for i in range(2), you're effectively accessing the first and second coordinate arrays, which are conventionally used for longitude (i=0) and latitude (i=1) in a 2D geographical grid within ESMF.
#
# src_lon_par is then a reference to the internal array within src_grid that is designated for longitude coordinates.
# src_lat_par is a reference to the internal array within src_grid designated for latitude coordinates.
# When you assign values to src_lon_par and src_lat_par:
#
# python
# Copy code
# src_lon_par[...] = src_lon.reshape((src_lon.shape[0], 1))
# src_lat_par[...] = src_lat.reshape((1, src_lat.shape[0]))
# You are directly modifying the content of these internal arrays in src_grid. The [...] syntax is used for an in-place operation that updates the entire array. This means src_lon_par and src_lat_par are indeed pointing to the contents of src_grid, and any changes made to these variables are reflected in the src_grid object itself. You're not just preparing ESMF to expect coordinate values; you're actively placing those values in the grid's coordinate system, effectively initializing src_grid with the specified longitude and latitude values.

# %%
src_grid
